# %%
# General lib
import pandas as pd

# geovdata package
import geovdata.sparql as sparql
import geovdata.kit as kit
from geovdata.ipython import infos

# geovpylib package
import geovpylib.database as db
import geovpylib.pks as pks


env = 'prod'
pk_project = pks.projects.switzerland_and_beyond
execute = True

# %% [markdown]
# ## Data from IDREF

# %%
data = pd.read_csv('./export_idref_dhs.csv', sep='\t')

data['DHS_'] = [uri[:-1] if uri[-1] == '/' else uri for uri in data['DHS']]

infos(data)
# Out:
# Shape:  (6996, 3) - extract:
#                               IDREF                                     DHS  \
# 0  http://www.idref.fr/256737665/id  http://hls-dhs-dss.ch/articles/028802/
# 1  http://www.idref.fr/200153501/id  http://hls-dhs-dss.ch/articles/045091/
# 2  http://www.idref.fr/237172658/id  http://hls-dhs-dss.ch/articles/046283/
# 3  http://www.idref.fr/234967145/id  http://hls-dhs-dss.ch/articles/028346/
# 4  http://www.idref.fr/192092146/id  http://hls-dhs-dss.ch/articles/007322/
#
#                                     DHS_
# 0  http://hls-dhs-dss.ch/articles/028802
# 1  http://hls-dhs-dss.ch/articles/045091
# 2  http://hls-dhs-dss.ch/articles/046283
# 3  http://hls-dhs-dss.ch/articles/028346
# 4  http://hls-dhs-dss.ch/articles/007322

# %% [markdown]
# ## Data from Geovistory

# %%
sparql.connect_geovistory(pk_project)

table = sparql.query("""
    select *
    where {
        # ?entity ontome:p1842/ontome:p1843 ?uri
    }
""")


table['pk_entity'] = [int(uri.replace('http://geovistory.org/resource/i', '')) for uri in table['entity']]
table['uri'] = table['uri'].str.replace('https://', 'http://')

infos(table)
# Out:
# >> SPARQL endpoint of Geovistory project 153 set.
# Shape:  (23980, 3) - extract:
#                                      entity  \
# 0  http://geovistory.org/resource/i10315216
# 1  http://geovistory.org/resource/i10315217
# 2  http://geovistory.org/resource/i10315218
# 3  http://geovistory.org/resource/i10315219
# 4  http://geovistory.org/resource/i10315220
#
#                                      uri  pk_entity
# 0  http://hls-dhs-dss.ch/articles/028377   10315216
# 1  http://hls-dhs-dss.ch/articles/044295   10315217
# 2  http://hls-dhs-dss.ch/articles/028424   10315218
# 3  http://hls-dhs-dss.ch/articles/011946   10315219
# 4  http://hls-dhs-dss.ch/articles/012028   10315220

# %% [markdown]
# ## Merging idref and geovistory

# %%
data = data.merge(table, left_on='DHS_', right_on='uri', how='left')
data['pk_entity'] = data['pk_entity'].astype(pd.Int64Dtype())

infos(data)
# Out:
# Shape:  (7012, 6) - extract:
#                               IDREF                                     DHS  \
# 0  http://www.idref.fr/256737665/id  http://hls-dhs-dss.ch/articles/028802/
# 1  http://www.idref.fr/200153501/id  http://hls-dhs-dss.ch/articles/045091/
# 2  http://www.idref.fr/237172658/id  http://hls-dhs-dss.ch/articles/046283/
# 3  http://www.idref.fr/234967145/id  http://hls-dhs-dss.ch/articles/028346/
# 4  http://www.idref.fr/192092146/id  http://hls-dhs-dss.ch/articles/007322/
#
#                                     DHS_  \
# 0  http://hls-dhs-dss.ch/articles/028802
# 1  http://hls-dhs-dss.ch/articles/045091
# 2  http://hls-dhs-dss.ch/articles/046283
# 3  http://hls-dhs-dss.ch/articles/028346
# 4  http://hls-dhs-dss.ch/articles/007322
#
#                                      entity  \
# 0  http://geovistory.org/resource/i10323059
# 1  http://geovistory.org/resource/i10316225
# 2  http://geovistory.org/resource/i10330969
# 3  http://geovistory.org/resource/i10329182
# 4  http://geovistory.org/resource/i10319423
#
#                                      uri  pk_entity
# 0  http://hls-dhs-dss.ch/articles/028802   10323059
# 1  http://hls-dhs-dss.ch/articles/045091   10316225
# 2  http://hls-dhs-dss.ch/articles/046283   10330969
# 3  http://hls-dhs-dss.ch/articles/028346   10329182
# 4  http://hls-dhs-dss.ch/articles/007322   10319423

# %% [markdown]
# ## Add infos into Geovistory

# %%
db.connect_geovistory(env, pk_project, execute)
# Out:
# [DB] Connecting to PRODUCTION Database ... Connected!

# %%
selection = data[pd.notna(data['pk_entity'])].drop_duplicates(subset=['IDREF', 'pk_entity'])

db.shortcuts.add_uris(selection['pk_entity'], selection['IDREF'])
# Out:
# [DB] Creating 6921 resources of class [967] ... Done in 0000y00m00d-00h00m02s
# [DB] Creating info_proj_rel of 6921 entities with project <153> ... Done in 0000y00m00d-00h00m01s
# [DB] Creating 6921 appellations ... Done in 0000y00m00d-00h00m03s
# [DB] Creating 6921 statements ... Updating metadata ... Done in 0000y00m00d-00h00m04s
# [DB] Creating info_proj_rel of 6921 entities with project <153> ... Done in 0000y00m00d-00h00m02s
# [DB] Creating 6921 statements ... Updating metadata ... Done in 0000y00m00d-00h00m03s
# [DB] Creating info_proj_rel of 6921 entities with project <153> ... Done in 0000y00m00d-00h00m02s

# %% [markdown]
# ## Export table for IDREF

# %%
to_export = data[['IDREF', 'DHS', 'entity']].drop_duplicates().copy()
to_export.rename(inplace=True, columns={'entity':'uri_geovistory'})

to_export.to_csv('./export_idref_dhs_with_geovistory.csv', sep='\t', index=False)

# %%
to_export[to_export.duplicated(subset=['IDREF'], keep=False)].sort_values('IDREF')
# Out:
#                                  IDREF  \
# 4576  http://www.idref.fr/027161625/id
# 4577  http://www.idref.fr/027161625/id
# 6723  http://www.idref.fr/027894134/id
# 6724  http://www.idref.fr/027894134/id
# 6204  http://www.idref.fr/076991954/id
# 6205  http://www.idref.fr/076991954/id
# 1155  http://www.idref.fr/081090994/id
# 1156  http://www.idref.fr/081090994/id
#
#                                          DHS  \
# 4576  http://hls-dhs-dss.ch/articles/018734/
# 4577  http://hls-dhs-dss.ch/articles/018734/
# 6723  http://hls-dhs-dss.ch/articles/014666/
# 6724  http://hls-dhs-dss.ch/articles/014666/
# 6204  http://hls-dhs-dss.ch/articles/014707/
# 6205  http://hls-dhs-dss.ch/articles/014707/
# 1155  http://hls-dhs-dss.ch/articles/031239/
# 1156  http://hls-dhs-dss.ch/articles/031239/
#
#                                uri_geovistory
# 4576  http://geovistory.org/resource/i2188083
# 4577  http://geovistory.org/resource/i2188346
# 6723    http://geovistory.org/resource/i27061
# 6724   http://geovistory.org/resource/i786979
# 6204    http://geovistory.org/resource/i25941
# 6205  http://geovistory.org/resource/i6516379
# 1155    http://geovistory.org/resource/i26222
# 1156  http://geovistory.org/resource/i6508101

# %%
to_export[to_export.duplicated(subset=['uri_geovistory'], keep=False)].sort_values('uri_geovistory').dropna()
# Out:
#                                  IDREF  \
# 69    http://www.idref.fr/027204936/id
# 102   http://www.idref.fr/033556091/id
# 1023  http://www.idref.fr/148830145/id
# 2018  http://www.idref.fr/033566836/id
# 2475  http://www.idref.fr/070506744/id
# 2759  http://www.idref.fr/084370599/id
# 3239  http://www.idref.fr/150814011/id
# 3250  http://www.idref.fr/028864697/id
# 3264  http://www.idref.fr/073318469/id
# 4052  http://www.idref.fr/026904667/id
# 4743  http://www.idref.fr/02840467X/id
# 5477  http://www.idref.fr/02868852X/id
# 6212  http://www.idref.fr/103128506/id
# 6302  http://www.idref.fr/031566499/id
# 6431  http://www.idref.fr/028492269/id
#
#                                          DHS  \
# 69    http://hls-dhs-dss.ch/articles/048826/
# 102   http://hls-dhs-dss.ch/articles/044657/
# 1023  http://hls-dhs-dss.ch/articles/031350/
# 2018  http://hls-dhs-dss.ch/articles/044400/
# 2475  http://hls-dhs-dss.ch/articles/015224/
# 2759  http://hls-dhs-dss.ch/articles/022484/
# 3239  http://hls-dhs-dss.ch/articles/028514/
# 3250  http://hls-dhs-dss.ch/articles/043138/
# 3264  http://hls-dhs-dss.ch/articles/027029/
# 4052  http://hls-dhs-dss.ch/articles/042218/
# 4743  http://hls-dhs-dss.ch/articles/047727/
# 5477  http://hls-dhs-dss.ch/articles/041513/
# 6212  http://hls-dhs-dss.ch/articles/026130/
# 6302  http://hls-dhs-dss.ch/articles/045434/
# 6431  http://hls-dhs-dss.ch/articles/027058/
#
#                              uri_geovistory
# 69    http://geovistory.org/resource/i26164
# 102   http://geovistory.org/resource/i26164
# 1023  http://geovistory.org/resource/i26164
# 2018  http://geovistory.org/resource/i26164
# 2475  http://geovistory.org/resource/i26164
# 2759  http://geovistory.org/resource/i26164
# 3239  http://geovistory.org/resource/i26164
# 3250  http://geovistory.org/resource/i26164
# 3264  http://geovistory.org/resource/i26164
# 4052  http://geovistory.org/resource/i26164
# 4743  http://geovistory.org/resource/i26164
# 5477  http://geovistory.org/resource/i26164
# 6212  http://geovistory.org/resource/i26164
# 6302  http://geovistory.org/resource/i26164
# 6431  http://geovistory.org/resource/i26164

# %%
to_export[pd.isna(to_export['uri_geovistory'])]
# Out:
#                                  IDREF  \
# 78    http://www.idref.fr/061092118/id
# 93    http://www.idref.fr/029499283/id
# 335   http://www.idref.fr/243940130/id
# 488   http://www.idref.fr/135783429/id
# 531   http://www.idref.fr/238306488/id
# ...                                ...
# 6710  http://www.idref.fr/274970775/id
# 6791  http://www.idref.fr/261834517/id
# 6794  http://www.idref.fr/267672403/id
# 6824  http://www.idref.fr/271205563/id
# 6915  http://www.idref.fr/16357104X/id
#
#                                          DHS uri_geovistory
# 78    http://hls-dhs-dss.ch/articles/049051/            NaN
# 93    http://hls-dhs-dss.ch/articles/043510/            NaN
# 335   http://hls-dhs-dss.ch/articles/044663/            NaN
# 488   http://hls-dhs-dss.ch/articles/014717/            NaN
# 531   http://hls-dhs-dss.ch/articles/020019/            NaN
# ...                                      ...            ...
# 6710  http://hls-dhs-dss.ch/articles/035522/            NaN
# 6791  http://hls-dhs-dss.ch/articles/007842/            NaN
# 6794  http://hls-dhs-dss.ch/articles/004606/            NaN
# 6824  http://hls-dhs-dss.ch/articles/015645/            NaN
# 6915  http://hls-dhs-dss.ch/articles/015813/            NaN
#
# [79 rows x 3 columns]
